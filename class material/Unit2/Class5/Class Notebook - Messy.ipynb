# %% [markdown]
# ### IMPORTANT:  CLASS SLIDES AND HANDOUT FOR THIS CLASS ARE IN CLASS4 FOLDER!!
#
# We'll be continuing from that into this lesson.  Look for their if you want background notes!

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('../data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[['Name', 'Pclass', 'Age']].mean()
# Out:
# Pclass     2.308642
# Age       29.699118
# dtype: float64

# %%
df.iloc[:100, [2, 3, 5]]
# Out:
#     Pclass                                               Name    Age
# 0        3                            Braund, Mr. Owen Harris  22.00
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.00
# 2        3                             Heikkinen, Miss. Laina  26.00
# 3        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.00
# 4        3                           Allen, Mr. William Henry  35.00
# 5        3                                   Moran, Mr. James    NaN
# 6        1                            McCarthy, Mr. Timothy J  54.00
# 7        3                     Palsson, Master. Gosta Leonard   2.00
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.00
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  14.00
# 10       3                    Sandstrom, Miss. Marguerite Rut   4.00
# 11       1                           Bonnell, Miss. Elizabeth  58.00
# 12       3                     Saundercock, Mr. William Henry  20.00
# ...

# %%
df[['Name', 'Age', 'Embarked']][:50].mean()
# Out:
# Age    27.472222
# dtype: float64

# %%
x = 23
x > 45
# Out:
# False

# %%
df[df['Age'] > 35]['Fare'].mean()
# Out:
# 43.96682073732718

# %%
df['Age'].between(35, 50)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21     False
# 22     False
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862     True
# 863    False
# 864    False
# 865     True
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871     True
# 872    False
# 873     True
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885     True
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[(df['Age'] > 35) & (df['Age'] < 50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 13            14         0       3
# 25            26         1       3
# 30            31         0       1
# 35            36         0       1
# 40            41         0       3
# 52            53         1       1
# 61            62         1       1
# 62            63         0       1
# 92            93         0       1
# 104          105         0       3
# 108          109         0       3
# 110          111         0       1
# 129          130         0       3
# 132          133         0       3
# 137          138         0       1
# 148          149         0       2
# 149          150         0       2
# 153          154         0       3
# 160          161         0       3
# 161          162         1       2
# 167          168         0       3
# 179          180         0       3
# 187          188         1       1
# 188          189         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df[df['Pclass'] == 3].shape
# Out:
# (491, 12)

# %%
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
df['Name'].duplicated().sum()
# Out:
# 0

# %%
df[df['Sex'] == 'male'].shape[0]
# Out:
# 577

# %%
df[df['Sex'] == 'male']['Survived'].mean()
# Out:
# 0.18890814558058924

# %%
df[df['Pclass'] < 3]['Survived'].mean()
# Out:
# 0.5575

# %%
df[df['Pclass'].between(1, 2)]['Survived'].mean()
# Out:
# 0.5575

# %%
df[(df['Sex'] == 'female' ) & (df['SibSp'] == 0)]['Survived'].mean()
# Out:
# 0.7873563218390804

# %%
df[df['Sex'] == 'female']['Name'].shape[0]
# Out:
# 314

# %%
df[df['Pclass'] == 3]['Age'].value_counts()
# Out:
# 22.0    20
# Name: Age, dtype: int64

# %%
df[df['Sex'] == 'male']['Embarked'].value_counts()
# Out:
# S    441
# C     95
# Q     41
# Name: Embarked, dtype: int64

# %%
df[(df['Pclass'] == 2) & (df['Sex']== 'male')].nlargest(10, 'Age')
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 672          673         0       2        Mitchell, Mr. Henry Michael  male
# 33            34         0       2              Wheadon, Mr. Edward H  male
# 570          571         1       2                 Harris, Mr. George  male
# 684          685         0       2  Brown, Mr. Thomas William Solomon  male
# 232          233         0       2          Sjostedt, Mr. Ernst Adolf  male
# 626          627         0       2     Kirkland, Rev. Charles Leonard  male
# 249          250         0       2      Carter, Rev. Ernest Courtenay  male
# 317          318         0       2               Moraweck, Dr. Ernest  male
# 582          583         0       2         Downton, Mr. William James  male
# 695          696         0       2         Chapman, Mr. Charles Henry  male
#
#       Age  SibSp  Parch       Ticket   Fare Cabin Embarked
# 672  70.0      0      0   C.A. 24580  10.50   NaN        S
# ...

# %%
df[df['Sex'] == 'female'].sort_values(['Fare', 'Age'], ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 341          342         1       1
# 88            89         1       1
# 742          743         1       1
# 311          312         1       1
# 299          300         1       1
# 380          381         1       1
# 716          717         1       1
# 700          701         1       1
# 779          780         1       1
# 730          731         1       1
# 689          690         1       1
# 856          857         1       1
# 318          319         1       1
# 268          269         1       1
# 609          610         1       1
# 498          499         0       1
# 708          709         1       1
# 297          298         0       1
# 195          196         1       1
# 31            32         1       1
# 325          326         1       1
# 269          270         1       1
# 337          338         1       1
# 319          320         1       1
# ...

# %%
df['Age']/df['Fare']
# Out:
# 0      3.034483
# 1      0.533084
# 2      3.280757
# 3      0.659134
# 4      4.347826
# 5           NaN
# 6      1.041215
# 7      0.094899
# 8      2.425157
# 9      0.465568
# 10     0.239521
# 11     2.184557
# 12     2.484472
# 13     1.247002
# 14     1.782486
# 15     3.437500
# 16     0.068670
# 17          NaN
# 18     1.722222
# 19          NaN
# 20     1.346154
# 21     2.615385
# 22     1.868181
# 23     0.788732
# 24     0.379597
# 25     1.210673
# 26          NaN
# 27     0.072243
# 28          NaN
# 29          NaN
#          ...
# 861    1.826087
# 862    1.851195
# 863         NaN
# 864    1.846154
# 865    3.230769
# 866    1.948291
# 867    0.613912
# 868         NaN
# 869    0.359283
# 870    3.292890
# 871    0.894315
# 872    6.600000
# 873    5.222222
# 874    1.166667
# 875    2.076125
# 876    2.031323
# 877    2.406343
# 878         NaN
# 879    0.673414
# 880    0.961538
# 881    4.179437
# 882    2.091911
# 883    2.666667
# 884    3.546099
# ...

# %%
my_dict = {
    'mykey1': 45
}

# %%
my_dict['mykey2'] = 37

# %%
df['New Column'] =
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AGE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-b186e5a0f346> in <module>
# ----> 1 df['AGE']
#
# ...

# %%
df['Total_Family_Size'] = df['Parch'] + df['SibSp']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Total_Family_Size
# 0      0         A/5 21171   7.2500   NaN        S                  1
# 1      0          PC 17599  71.2833   C85        C                  1
# 2      0  STON/O2. 3101282   7.9250   NaN        S                  0
# ...

# %%
# %timeit df['Demographic'] = np.where(df['Age']> 75, 'Getting up there', 'Bloom of Your Youth')
# Out:
# 389 µs ± 6.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df['Demographic'].value_counts()
# Out:
# Bloom of Your Youth    890
# Getting up there         1
# Name: Demographic, dtype: int64

# %%
df[(df['Survived'] == 1) & (df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 19            20         1       3
# 22            23         1       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 61            62         1       1
# 66            67         1       2
# 68            69         1       3
# ...

# %%
conditions = [
    (df['Survived'] == 1) & (df['Sex'] == 'female'),
    (df['Survived'] == 1) & (df['Sex'] == 'male'),
    (df['Survived'] == 0) & (df['Sex'] == 'female'),
    (df['Survived'] == 0) & (df['Sex'] == 'male')
]

results = [
    'Female-Survived',
    'Male-Survived',
    'Female-Died',
    'Male-Died',
]

# %%
# %timeit df['Status'] = np.select(conditions, results, 'Other')
# Out:
# 258 µs ± 3.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df['Status'].value_counts()
# Out:
# Male-Died          468
# Female-Survived    233
# Male-Survived      109
# Female-Died         81
# Name: Status, dtype: int64

# %%
def over_75(val):
    if val > 75:
        return 'Getting up there'
    else:
        return 'In the Bloom of Your Youth'

# %%
# %timeit df['Demographic'] = df['Age'].apply(over_75)
# Out:
# 434 µs ± 771 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def get_status(val):
    if val['Survived'] == 1 and val['Sex'] == 'female':
        return 'Female-Survived'
    elif val['Survived'] == 1 and val['Sex'] == 'male':
        return 'Male-Survived'
    elif val['Survived'] == 0 and val['Sex'] == 'female':
        return 'Female-Died'
    elif val['Survived'] == 0 and val['Sex'] == 'male':
        return 'Male-Died'
    else:
        return 'Other'

# %%
# %timeit df['Status'] = df.apply(get_status, axis=1)
# Out:
# 29.9 ms ± 4.07 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# PassengerId          891 non-null int64
# Survived             891 non-null int64
# Pclass               891 non-null int64
# Name                 891 non-null object
# Sex                  891 non-null object
# Age                  714 non-null float64
# SibSp                891 non-null int64
# Parch                891 non-null int64
# Ticket               891 non-null object
# Fare                 891 non-null float64
# Cabin                204 non-null object
# Embarked             889 non-null object
# Total_Family_Size    891 non-null int64
# Demographic          891 non-null object
# Status               891 non-null object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 104.5+ KB

# %%
df['New Column'] = 23

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Total_Family_Size  \
# 0      0         A/5 21171   7.2500   NaN        S                  1
# 1      0          PC 17599  71.2833   C85        C                  1
# 2      0  STON/O2. 3101282   7.9250   NaN        S                  0
# ...

# %%
# ?pd.cut

# %%
df['Age-Demographic'] = pd.cut(df['Age'], bins=[0, 13, 35, 65, 85, 100], labels=['Youngest', 'Young', 'Middle', 'Older', 'Old'])

# %%
df['Age-Demographic'].value_counts()
# Out:
# Young       346
# Middle      188
# Youngest    100
# Older        69
# Old          11
# Name: Age-Demographic, dtype: int64

# %%
# %matplotlib inline
df['Age'].hist(bins=5)

# %%
class_map = {
    1: 'VIP', 
    2: 'Business Class',
    3: 'Coach'
}

df['Pclass'].map(class_map)
# Out:
# 0               Coach
# 1                 VIP
# 2               Coach
# 3                 VIP
# 4               Coach
# 5               Coach
# 6                 VIP
# 7               Coach
# 8               Coach
# 9      Business Class
# 10              Coach
# 11                VIP
# 12              Coach
# 13              Coach
# 14              Coach
# 15     Business Class
# 16              Coach
# 17     Business Class
# 18              Coach
# 19              Coach
# 20     Business Class
# 21     Business Class
# 22              Coach
# 23                VIP
# 24              Coach
# 25              Coach
# 26              Coach
# 27                VIP
# 28              Coach
# 29              Coach
#             ...
# 861    Business Class
# 862               VIP
# 863             Coach
# 864    Business Class
# 865    Business Class
# 866    Business Class
# 867               VIP
# 868             Coach
# 869             Coach
# 870             Coach
# ...

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].mean().to_dict()
# Out:
# {('female', 1): 0.9680851063829787,
#  ('female', 2): 0.9210526315789473,
#  ('female', 3): 0.5,
#  ('male', 1): 0.36885245901639346,
#  ('male', 2): 0.1574074074074074,
#  ('male', 3): 0.13544668587896252}

# %%
df['Status'].replace(['Male-Died', 'Female-Survived'], 'Other')
# Out:
# 0              Other
# 1              Other
# 2              Other
# 3              Other
# 4              Other
# 5              Other
# 6              Other
# 7              Other
# 8              Other
# 9              Other
# 10             Other
# 11             Other
# 12             Other
# 13             Other
# 14       Female-Died
# 15             Other
# 16             Other
# 17     Male-Survived
# 18       Female-Died
# 19             Other
# 20             Other
# 21     Male-Survived
# 22             Other
# 23     Male-Survived
# 24       Female-Died
# 25             Other
# 26             Other
# 27             Other
# 28             Other
# 29             Other
#            ...
# 861            Other
# 862            Other
# 863      Female-Died
# 864            Other
# 865            Other
# 866            Other
# 867            Other
# 868            Other
# 869    Male-Survived
# 870            Other
# 871            Other
# 872            Other
# ...

# %%
df.fillna()
