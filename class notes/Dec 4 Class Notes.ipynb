# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("/Users/bianca/Documents/GitHub/DAT-10-14/class material/Unit3/Data/hitters.csv")

# %%
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
def mse(data, target):
    error = data.mean() - target
    return np.mean(error**2)

# %%
X_bat = df.loc[:,df.columns != 'Salary']
X_bat=X_bat.select_dtypes(include=np.number)
y_bat = df['Salary']

# %%
query = df.RBI < 100

# %%
left = df[query].copy()
right = df[~query].copy()

# %%
left_size = mse(left.index, y_bat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-553dfeae4808> in <module>
# ----> 1 left_size = mse(left.index, y_bat)
#
# <ipython-input-6-9e2589c32c31> in mse(data, target)
#       1 def mse(data, target):
# ----> 2     error = data.mean() - target
#       3     return np.mean(error**2)
#
# AttributeError: 'Int64Index' object has no attribute 'mean'

# %%
right_size = mse(right.index,y)

# %%
info_gain = total_size - (right_size/df_size*(right_error) - left_size/df_size*(left_error))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-638197ef78cf> in <module>
# ----> 1 info_gain = total_size - (right_size/df_size*(right_error) - left_size/df_size*(left_error))
#
# NameError: name 'total_size' is not defined

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()

# %%
tree.get_params()
# Out:
# {'criterion': 'mse',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': False,
#  'random_state': None,
#  'splitter': 'best'}

# %%
df.columns
# Out:
# Index(['AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years', 'CAtBat',
#        'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'League', 'Division',
#        'PutOuts', 'Assists', 'Errors', 'Salary', 'NewLeague'],
#       dtype='object')

# %%
rf.max_features = 0.5

# %%
X = df.loc[:, df.isnull().sum()==0]

# %%
X.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N
# 5   336     194      A        W      282      421      25   750.0         A

# %%
y[X.index]
# Out:
# 1       475.000
# 2       480.000
# 3       500.000
# 4        91.500
# 5       750.000
# 6        70.000
# 7       100.000
# 8        75.000
# 9      1100.000
# 10      517.143
# 11      512.500
# 12      550.000
# 13      700.000
# 14      240.000
# 16      775.000
# 17      175.000
# 19      135.000
# 20      100.000
# 21      115.000
# 23      600.000
# 24      776.667
# 25      765.000
# 26      708.333
# 27      750.000
# 28      625.000
# 29      900.000
# 31      110.000
# 33      612.500
# 34      300.000
# 35      850.000
#          ...
# 287     350.000
# 288     326.667
# 289     250.000
# 290     740.000
# 291     425.000
# 293     925.000
# 294     185.000
# 295     920.000
# 296     286.667
# 297     245.000
# 299     235.000
# 300    1150.000
# 301     160.000
# 303     425.000
# 304     900.000
# 306     500.000
# 307     277.500
# 308     750.000
# 309     160.000
# 310    1300.000
# 311     525.000
# 312     550.000
# 313    1600.000
# 314     120.000
# ...

# %%
y.isnull().sum()
# Out:
# 0

# %%
df = df.dropna()

# %%
X = df.loc[:, df.columns != 'Salary']
X=X.select_dtypes(include=np.number)
y = df['Salary']

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# %%
rf.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
rf.estimators_
# Out:
# [DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=1608637542, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=1273642419, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
# ...

# %%
#https://towardsdatascience.com/random-forest-in-python-24d0893d51c0

# %%
train = pd.read_csv("/Users/bianca/Documents/GitHub/DAT-10-14/class material/Unit3/Data/iowa_housing/train.csv", usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 70, 77, 80])

# %%
test = pd.read_csv("/Users/bianca/Documents/GitHub/DAT-10-14/class material/Unit3/Data/iowa_housing/test.csv", usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 70, 77])

# %%
train.isnull().sum()
# Out:
# MSSubClass     0
# OverallQual    0
# OverallCond    0
# YearBuilt      0
# 1stFlrSF       0
# 2ndFlrSF       0
# GrLivArea      0
# FullBath       0
# HalfBath       0
# ScreenPorch    0
# YrSold         0
# SalePrice      0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# MSSubClass     0
# OverallQual    0
# OverallCond    0
# YearBuilt      0
# 1stFlrSF       0
# 2ndFlrSF       0
# GrLivArea      0
# FullBath       0
# HalfBath       0
# ScreenPorch    0
# YrSold         0
# dtype: int64

# %%
X_train, y_train = train.loc[:, train.columns != 'SalePrice'], np.log(train['SalePrice'])

# %%
y_train.hist();

# %%
#this exercise uses the root mean R squared error

# %%
def rmse(estimator, X, y):
    preds  = estimator.predict(X)
    error = np.sqrt(np.mean((preds - y)**2))
    return error

# %%
#the above is the root mean log square error

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()

#cross validating how many samples should we use
samples_per_leaf = [1, 5, 10, 15, 25, 50]
rf_scores = []

#for every value in list, set the value, then look at the validation scores
#append the average value of the score and corresponding value

for num_samples in samples_per_leaf:
    rf.set_params(min_samples_leaf=num_samples)
    scores = cross_val_score(estimator=rf, X=X_train, y=y_train, scoring=rmse, cv=10)
    rf_scores.append((np.mean(scores), num_samples))
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
rf_scores
# Out:
# [(0.1593217479432386, 1),
#  (0.16438489898985392, 5),
#  (0.16853883755348592, 10),
#  (0.1711822252853738, 15),
#  (0.17996686799356826, 25),
#  (0.19637850067724327, 50)]

# %%
rf.set_params(min_samples_leaf=1)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators='warn',
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf.fit(X_train, y_train)
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
test['Prediction'] = rf.predict(test)

# %%
np.exp(test.Prediction)
# Out:
# 0       119380.960076
# 1       148096.876236
# 2       179604.342605
# 3       183185.673111
# 4       203448.668805
# 5       182070.838090
# 6       160870.001013
# 7       171417.618293
# 8       194009.242623
# 9       114780.085720
# 10      198224.719014
# 11       88317.847136
# 12       89190.883055
# 13      151860.501742
# 14      150169.069527
# 15      456281.926757
# 16      247815.115556
# 17      335717.316548
# 18      277987.489548
# 19      488101.278594
# 20      307655.603489
# 21      218532.734046
# 22      177950.495967
# 23      172689.345137
# 24      174606.637897
# 25      214972.058837
# 26      338323.003544
# 27      252846.573529
# 28      198103.543100
# 29      193869.204164
#             ...
# 1429     70998.614900
# 1430    137871.721814
# 1431     64132.609987
# 1432    132976.335867
# 1433     58291.551175
# 1434    289259.977804
# 1435    276118.217921
# 1436    192894.470060
# 1437    152577.223995
# 1438    251939.297118
# ...

# %%
output = pd.DataFrame({
    'Id'       : np.arange(1461, 2920),
    'SalePrice': np.exp(test.Prediction)
})

# %%
output.head()
# Out:
#      Id      SalePrice
# 0  1461  119380.960076
# 1  1462  148096.876236
# 2  1463  179604.342605
# 3  1464  183185.673111
# 4  1465  203448.668805

# %%
output.to_csv("/Users/bianca/Documents/GitHub/DAT-10-14/class material/Unit3//data/iowa_housing/sample_predictions.csv", index=False)
